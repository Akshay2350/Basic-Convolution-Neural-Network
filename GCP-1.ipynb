# %%
# !git clone https://github.com/Akshay2350/Basic-Convolution-Neural-Network
# Out:
# Cloning into 'Basic-Convolution-Neural-Network'...
# remote: Enumerating objects: 10026, done.
# remote: Total 10026 (delta 0), reused 0 (delta 0), pack-reused 10026
# Receiving objects: 100% (10026/10026), 216.40 MiB | 38.18 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Checking out files: 100% (10010/10010), done.

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('Basic-Convolution-Neural-Network/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory('Basic-Convolution-Neural-Network/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
classifier.fit_generator(training_set,
                         steps_per_epoch = 8000/100,
                         epochs = 25,
                         validation_data = test_set,
                         validation_steps = 2000/100)
# Out:
# Epoch 1/25
# 80/80 [==============================] - 27s 334ms/step - loss: 0.6979 - acc: 0.5336 - val_loss: 0.6731 - val_acc: 0.5687
# Epoch 2/25
# 80/80 [==============================] - 26s 320ms/step - loss: 0.6814 - acc: 0.5664 - val_loss: 0.6651 - val_acc: 0.6031
# Epoch 3/25
# 80/80 [==============================] - 26s 322ms/step - loss: 0.6558 - acc: 0.6262 - val_loss: 0.6432 - val_acc: 0.6687
# Epoch 4/25
# 80/80 [==============================] - 26s 320ms/step - loss: 0.6289 - acc: 0.6465 - val_loss: 0.5895 - val_acc: 0.6907
# Epoch 5/25
# 80/80 [==============================] - 26s 322ms/step - loss: 0.6154 - acc: 0.6617 - val_loss: 0.6144 - val_acc: 0.6641
# Epoch 6/25
# 80/80 [==============================] - 26s 320ms/step - loss: 0.6173 - acc: 0.6598 - val_loss: 0.5676 - val_acc: 0.7000
# Epoch 7/25
# 80/80 [==============================] - 25s 317ms/step - loss: 0.5905 - acc: 0.6871 - val_loss: 0.5396 - val_acc: 0.7228
# Epoch 8/25
# ...

# %%
# Making new predictions

import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Basic-Convolution-Neural-Network/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
  prediction = 'cat'

print(prediction)
# Out:
# dog
